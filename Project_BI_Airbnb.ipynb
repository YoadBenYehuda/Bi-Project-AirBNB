# %% [markdown]
# **BI Project - Boston Airbnb**

# %% [markdown]
# #Buisness case and KPIs

# %% [markdown]
# ![WhatsApp Image 2023-07-02 at 20.21.42.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Data Warehouse

# %% [markdown]
# ![WhatsApp Image 2023-07-02 at 20.23.26.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **ERD**

# %% [markdown]
# ![ERD.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **USECASE**

# %% [markdown]
# ![Use Case.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #הגדרה ומימוש ETL

# %% [markdown]
# ![WhatsApp Image 2023-07-02 at 20.25.32.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Data

# %%
# !pip install jsonpath_ng

# %%
Requirement already satisfied: jsonpath_ng in /usr/local/lib/python3.10/dist-packages (1.5.3)
Requirement already satisfied: ply in /usr/local/lib/python3.10/dist-packages (from jsonpath_ng) (3.11)
Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from jsonpath_ng) (4.4.2)
Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from jsonpath_ng) (1.16.0)

# %%
import os
import json
import numpy as np
import pandas as pd
import sqlite3
import functools as ft
import matplotlib.pyplot as plt
from abc import ABC, abstractmethod
from jsonpath_ng import parse
from enum import Enum
# %matplotlib inline

# %%
with open("listings.json", "r") as file:
    data = json.load(file)
    for item in data:
      item["id"] = str(item["id"])
      #item["bathrooms"] = float(item["bathrooms"])
      #item["bedrooms"] = int(item["bedrooms"])
      #item["beds"] = float(item["beds"])


data[:2]
# Out:
# [{'id': '12147973',
#   'listing_url': 'https://www.airbnb.com/rooms/12147973',
#   'scrape_id': 20200000000000,
#   'last_scraped': '07/09/2016',
#   'name': 'Sunny Bungalow in the City',
#   'summary': 'Cozy, sunny, family home.  Master bedroom high ceilings. Deck, garden with hens, beehives & play structure.   Short walk to charming village with  attractive stores, groceries & local restaurants. Friendly neighborhood. Access public transportation.',
#   'space': 'The house has an open and cozy feel at the same time.  The living room has a flat screen TV.  The kitchen has all you need for cooking.  We prefer you buy your food but can use the organic oils, herbs, etc.   The yard can be seen from sitting room and when the weather allows, the yard is a place children can lose themselves in a safe way.  We have 2 bee hives, 6 hens fenced in (sometimes they get out of their coop area & into the yard), 2 rabbits in a hutch and play structure.',
#   'description': "Cozy, sunny, family home.  Master bedroom high ceilings. Deck, garden with hens, beehives & play structure.   Short walk to charming village with  attractive stores, groceries & local restaurants. Friendly neighborhood. Access public transportation. The house has an open and cozy feel at the same time.  The living room has a flat screen TV.  The kitchen has all you need for cooking.  We prefer you buy your food but can use the organic oils, herbs, etc.   The yard can be seen from sitting room and when the weather allows, the yard is a place children can lose themselves in a safe way.  We have 2 bee hives, 6 hens fenced in (sometimes they get out of their coop area & into the yard), 2 rabbits in a hutch and play structure. You will have access to 2 bedrooms, a living room, kitchen, bathrooms, and yard. Roslindale is quiet, convenient and friendly.  For Southern food try Redd's in Rozzie.  Italian Delfino's or Sophia's Grotto are great. Birch St Bistro has nice atmostphere--a little pric",
#   'experiences_offered': 'none',
#   'neighborhood_overview': "Roslindale is quiet, convenient and friendly.  For Southern food try Redd's in Rozzie.  Italian Delfino's or Sophia's Grotto are great. Birch St Bistro has nice atmostphere--a little pricier.   If you are cooking the Fish Market has fresh fish daily; Tony's makes his own sausages and has Italian foods;  for  a wide variety of delicious cheeses and chocolates go to the Cheese Cellar on Birch St.",
#   'notes': '',
#   'transit': 'The bus stop is 2 blocks away, and frequent. Bus is about a 10 minute ride to the Orange line, forest hills. The commuter rail into down town is a 6 minute walk from our home.  Walking is pleasant and restaurants, shops and grocery store are all a 6 minute walk away.',
#   'access': 'You will have access to 2 bedrooms, a living room, kitchen, bathrooms, and yard.',
#   'interaction': '',
#   'house_rules': "Clean up and treat the home the way you'd like your home to be treated.  No smoking.",
#   'thumbnail_url': 'https://a2.muscache.com/im/pictures/c0842db1-ee98-4fe8-870b-d1e2af33855d.jpg?aki_policy=small',
#   'medium_url': 'https://a2.muscache.com/im/pictures/c0842db1-ee98-4fe8-870b-d1e2af33855d.jpg?aki_policy=medium',
#   'picture_url': 'https://a2.muscache.com/im/pictures/c0842db1-ee98-4fe8-870b-d1e2af33855d.jpg?aki_policy=large',
#   'xl_picture_url': 'https://a2.muscache.com/im/pictures/c0842db1-ee98-4fe8-870b-d1e2af33855d.jpg?aki_policy=x_large',
#   'host_id': 31303940,
#   'host_url': 'https://www.airbnb.com/users/show/31303940',
#   'host_name': 'Virginia',
#   'host_since': '15/04/2015',
#   'host_location': 'Boston, Massachusetts, United States',
#   'host_about': 'We are country and city connecting in our deck and garden. Enjoy our music room, books and flat screen TV with the pastoral backyard of hens, bees, rabbits and an organic garden.  ',
#   'host_response_time': 'N/A',
#   'host_response_rate': 'N/A',
#   'host_acceptance_rate': 'N/A',
#   'host_is_superhost': 'f',
#   'host_thumbnail_url': 'https://a2.muscache.com/im/pictures/5936fef0-ba16-45bd-ac33-9226137d0763.jpg?aki_policy=profile_small',
#   'host_picture_url': 'https://a2.muscache.com/im/pictures/5936fef0-ba16-45bd-ac33-9226137d0763.jpg?aki_policy=profile_x_medium',
#   'host_neighbourhood': 'Roslindale',
#   'host_listings_count': 1,
#   'host_total_listings_count': 1,
#   'host_verifications': "['email', 'phone', 'facebook', 'reviews']",
#   'host_has_profile_pic': 't',
#   'host_identity_verified': 'f',
#   'street': 'Birch Street, Boston, MA 02131, United States',
#   'neighbourhood': 'Roslindale',
#   'neighbourhood_cleansed': 'Roslindale',
#   'neighbourhood_group_cleansed': '',
#   'city': 'Boston',
#   'state': 'MA',
#   'zipcode': '2131',
#   'market': 'Boston',
#   'smart_location': 'Boston, MA',
#   'country_code': 'US',
#   'country': 'United States',
#   'latitude': 42.28,
#   'longitude': -71.13,
#   'is_location_exact': 't',
#   'property_type': 'House',
#   'room_type': 'Entire home/apt',
#   'accommodates': 4,
#   'bathrooms': 1,
#   'bedrooms': 2,
#   'beds': 3,
#   'bed_type': 'Real Bed',
#   'amenities': '{TV,"Wireless Internet",Kitchen,"Free Parking on Premises","Pets live on this property",Dog(s),Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Fire Extinguisher",Essentials,Shampoo,"Laptop Friendly Workspace"}',
#   'square_feet': None,
#   'price': 250,
#   'weekly_price': None,
#   'monthly_price': None,
#   'security_deposit': None,
#   'cleaning_fee': 35,
#   'guests_included': 1,
#   'extra_people': 0,
#   'minimum_nights': 2,
#   'maximum_nights': 1125,
#   'calendar_updated': '2 weeks ago',
#   'has_availability': '',
#   'availability_30': 0,
#   'availability_60': 0,
#   'availability_90': 0,
#   'availability_365': 0,
#   'calendar_last_scraped': '06/09/2016',
#   'number_of_reviews': 0,
#   'first_review': '',
#   'last_review': '',
#   'review_scores_rating': None,
#   'review_scores_accuracy': None,
#   'review_scores_cleanliness': None,
#   'review_scores_checkin': None,
#   'review_scores_communication': None,
#   'review_scores_location': None,
#   'review_scores_value': None,
#   'requires_license': 'f',
#   'license': '',
#   'jurisdiction_names': '',
#   'instant_bookable': 'f',
#   'cancellation_policy': 'moderate',
#   'require_guest_profile_picture': 'f',
#   'require_guest_phone_verification': 'f',
#   'calculated_host_listings_count': 1,
#   'reviews_per_month': None},
#  {'id': '3075044',
#   'listing_url': 'https://www.airbnb.com/rooms/3075044',
#   'scrape_id': 20200000000000,
#   'last_scraped': '07/09/2016',
#   'name': 'Charming room in pet friendly apt',
#   'summary': "Charming and quiet room in a second floor 1910 condo building. The room has a full size bed, darkening curtains, window A/C unit. It's quiet because it's in the back of the house. Shared bathroom. Guests can use kitchen, living room. Pet friendly.",
#   'space': 'Small but cozy and quite room with a full size bed. Ample street parking.',
#   'description': "Charming and quiet room in a second floor 1910 condo building. The room has a full size bed, darkening curtains, window A/C unit. It's quiet because it's in the back of the house. Shared bathroom. Guests can use kitchen, living room. Pet friendly. Small but cozy and quite room with a full size bed. Ample street parking. Apt has one more bedroom (which I use) and large living space and kitchen that you can use.  Possibility to do laundry. Two porches. If I am at home, I am likely working in my home office, which is a separate room. I can help you settle in and give you tips and directions on the neighborhood and Boston.  The room is in Roslindale, a diverse and primarily residential neighborhood of Boston. It's well connected via public transportation to other neighborhoods and easy to access by car. Roslindale Square is a nice business district with supermarkets. banks, a bakery, etc. (See my Guidebook for some recommendations). The Arnold Arboretum is just steps away. Plenty of safe s",
#   'experiences_offered': 'none',
#   'neighborhood_overview': "The room is in Roslindale, a diverse and primarily residential neighborhood of Boston. It's well connected via public transportation to other neighborhoods and easy to access by car. Roslindale Square is a nice business district with supermarkets. banks, a bakery, etc. (See my Guidebook for some recommendations). The Arnold Arboretum is just steps away.",
#   'notes': "If you don't have a US cell phone, you can text me using (SENSITIVE CONTENTS HIDDEN).",
#   'transit': 'Plenty of safe street parking. Bus stops a few hundred feet from home. Buses 35, 36, or 37 will take you to the Forest Hills subway station is approximately 10 minutes. The buses are frequent during the week, less frequent during the weekend. However, many more buses leave Roslindale Sq., which is just 5 minutes away. Commuter rail is also down the road: more expensive but will take you downtown (Copley and South Station) in less than 20 minutes. Does not run on Sundays. The station is Roslindale Village on the Needham Heights line.',
#   'access': 'Apt has one more bedroom (which I use) and large living space and kitchen that you can use.  Possibility to do laundry. Two porches.',
#   'interaction': 'If I am at home, I am likely working in my home office, which is a separate room. I can help you settle in and give you tips and directions on the neighborhood and Boston. ',
#   'house_rules': 'Pet friendly but please confirm with me if the pet you are planning on bringing with you is OK. I have a cute and quiet mixed chihuahua. I could accept more guests (for an extra fee) but this also needs to be confirmed beforehand. Also friends traveling together could sleep in separate beds for an extra fee (the second bed is either a sofa bed or inflatable bed). Smoking is only allowed on the porch.',
#   'thumbnail_url': 'https://a1.muscache.com/im/pictures/39327812/df0f1aab_original.jpg?aki_policy=small',
#   'medium_url': 'https://a1.muscache.com/im/pictures/39327812/df0f1aab_original.jpg?aki_policy=medium',
#   'picture_url': 'https://a1.muscache.com/im/pictures/39327812/df0f1aab_original.jpg?aki_policy=large',
#   'xl_picture_url': 'https://a1.muscache.com/im/pictures/39327812/df0f1aab_original.jpg?aki_policy=x_large',
#   'host_id': 2572247,
#   'host_url': 'https://www.airbnb.com/users/show/2572247',
#   'host_name': 'Andrea',
#   'host_since': '07/06/2012',
#   'host_location': 'Boston, Massachusetts, United States',
#   'host_about': 'I live in Boston and I like to travel and have travelers staying at my place.',
#   'host_response_time': 'within an hour',
#   'host_response_rate': '100%',
#   'host_acceptance_rate': '100%',
#   'host_is_superhost': 'f',
#   'host_thumbnail_url': 'https://a2.muscache.com/im/users/2572247/profile_pic/1442235897/original.jpg?aki_policy=profile_small',
#   'host_picture_url': 'https://a2.muscache.com/im/users/2572247/profile_pic/1442235897/original.jpg?aki_policy=profile_x_medium',
#   'host_neighbourhood': 'Roslindale',
#   'host_listings_count': 1,
#   'host_total_listings_count': 1,
#   'host_verifications': "['email', 'phone', 'facebook', 'linkedin', 'amex', 'reviews', 'jumio']",
#   'host_has_profile_pic': 't',
#   'host_identity_verified': 't',
#   'street': 'Pinehurst Street, Boston, MA 02131, United States',
#   'neighbourhood': 'Roslindale',
#   'neighbourhood_cleansed': 'Roslindale',
#   'neighbourhood_group_cleansed': '',
#   'city': 'Boston',
#   'state': 'MA',
#   'zipcode': '2131',
#   'market': 'Boston',
#   'smart_location': 'Boston, MA',
#   'country_code': 'US',
#   'country': 'United States',
#   'latitude': 42.29,
#   'longitude': -71.13,
#   'is_location_exact': 't',
#   'property_type': 'Apartment',
#   'room_type': 'Private room',
#   'accommodates': 2,
#   'bathrooms': 1,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'amenities': '{TV,Internet,"Wireless Internet","Air Conditioning",Kitchen,"Pets Allowed","Pets live on this property",Dog(s),Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","Fire Extinguisher",Essentials,Shampoo,"Lock on Bedroom Door",Hangers,"Hair Dryer",Iron}',
#   'square_feet': None,
#   'price': 65,
#   'weekly_price': 400,
#   'monthly_price': None,
#   'security_deposit': 95,
#   'cleaning_fee': 10,
#   'guests_included': 0,
#   'extra_people': 0,
#   'minimum_nights': 2,
#   'maximum_nights': 15,
#   'calendar_updated': 'a week ago',
#   'has_availability': '',
#   'availability_30': 26,
#   'availability_60': 54,
#   'availability_90': 84,
#   'availability_365': 359,
#   'calendar_last_scraped': '06/09/2016',
#   'number_of_reviews': 36,
#   'first_review': '01/06/2014',
#   'last_review': '13/08/2016',
#   'review_scores_rating': 94,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 9,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 9,
#   'review_scores_value': 9,
#   'requires_license': 'f',
#   'license': '',
#   'jurisdiction_names': '',
#   'instant_bookable': 't',
#   'cancellation_policy': 'moderate',
#   'require_guest_profile_picture': 'f',
#   'require_guest_phone_verification': 'f',
#   'calculated_host_listings_count': 1,
#   'reviews_per_month': 1.3}]

# %% [markdown]
# ###  Abstract Base Calss (ABC) for mutual methods

# %%
class Interface(ABC):

    @abstractmethod
    def get_data_by_field(self, field_name):
        """Fetch the data by given feild name """

    @abstractmethod
    def get_data_by_id(self, id):
        """Fetch the data by given ID  """

    @abstractmethod
    def get(self):
        """Fetch all data """

# %% [markdown]
# ### Transform Operations
# inherithed from Enum - class that automatic enumrate the variables

# %%
class TransformMask(Enum):
    # add here any masks you want
    CLEAN_STRING = ".strip().lower()"
    CAPITAL_LETTER = ".strip().lower().title()"
    CLEAN_NUM = ""

# %% [markdown]
# ### Database Class - Define Common Properties for Source, Target, Mapping

# %%
class Database:
    def __init__(self):
        self.db = {
            "source": [],
            "destination": [],
            "transform": [],
            "mapping": []
        }
        #Fact
        #id
        self.add_source(1, "id", "str")
        self.add_destination(1, "id", "str", "fact")
        self.add_transform(1, "CLEAN_STRING")
        self.add_mapping(1, 1, 1, 1, "fact")
        #price
        self.add_source(2, "price", "int")
        self.add_destination(2, "price", "float", "fact")
        self.add_transform(2, "CLEAN_NUM")
        self.add_mapping(2, 2, 2, 2, "fact")
        #dim_property
        #city
        self.add_source(3, "city", "str")
        self.add_destination(3, "city", "str", "dim_location")
        self.add_transform(3, "CLEAN_STRING")
        self.add_mapping(3, 3, 3, 3, "dim_property")
        #neighbourhood
        self.add_source(4, "neighbourhood", "str")
        self.add_destination(4, "neighbourhood", "str", "dim_location")
        self.add_transform(4, "CLEAN_STRING")
        self.add_mapping(4, 4, 4, 4, "dim_property")
        #property_type
        self.add_source(5, "property_type", "str")
        self.add_destination(5, "property_type", "str", "dim_property")
        self.add_transform(5, "CLEAN_STRING")
        self.add_mapping(5, 5, 5, 5, "dim_property")
        #room_type
        self.add_source(6, "room_type", "str")
        self.add_destination(6, "room_type", "str", "dim_property")
        self.add_transform(6, "CLEAN_STRING")
        self.add_mapping(6, 6, 6, 6, "dim_property")
        #accommodates
        self.add_source(7, "accommodates", "int")
        self.add_destination(7, "accommodates", "int", "dim_property")
        self.add_transform(7, "CLEAN_NUM")
        self.add_mapping(7, 7, 7, 7, "dim_property")
        #bathrooms
        self.add_source(8, "bathrooms", "int")
        self.add_destination(8, "bathrooms", "int", "dim_property")
        self.add_transform(8, "CLEAN_NUM")
        self.add_mapping(8, 8, 8, 8, "dim_property")
        #bedrooms
        self.add_source(9, "bedrooms", "int")
        self.add_destination(9, "bedrooms", "int", "dim_property")
        self.add_transform(9, "CLEAN_NUM")
        self.add_mapping(9, 9, 9, 9, "dim_property")
        #beds
        self.add_source(10, "beds", "int")
        self.add_destination(10, "beds", "int", "dim_property")
        self.add_transform(10, "CLEAN_NUM")
        self.add_mapping(10, 10, 10, 10, "dim_property")

    def add_source(self, id, field, typ):
            self.db["source"].append({
                "id": id,
                "source_field_name": field,
                "source_field_mapping": field,
                "source_field_type": typ,
                "is_required": True,
            })

    def add_destination(self, id, field, typ, destination):
        self.db["destination"].append({
            "id": id,
            "destination_field_name": field,
            "destination_field_mapping": field,
            "destination_field_type": typ,
            "default_value": "n/a",
            "destination_table": destination,
        })

    def add_transform(self, id, mask):
        self.db["transform"].append({
            "id": id,
            "transform_mask": mask,
        })

    def add_mapping(self, id, source, dest, transform, destination):
      self.db["mapping"].append({
          "id": id,
          "mapping_source": source,
          "mapping_destination": dest,
          "mapping_transform": transform,
          "destination_table": destination,
        })


    @property
    def get_data_source_target_mapping(self):
      return self.db

# %% [markdown]
# ### Source class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Source(Interface, Database):
    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("source")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id") == self.id:
                return x
        return None

# %% [markdown]
# ### Target class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Target(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("destination")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

# %% [markdown]
# ### Transform Class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Transform(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("transform", [])

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

# %% [markdown]
# ### Mapping class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Mappings(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("mapping")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

    def get_data_by_field(self, field_name):
        return None

# %% [markdown]
# ### Format Class - JSON
#
# Search the source data value inside a JSON file

# %%
class JsonQuery:
    def __init__(self, json_path, json_data):
        self.json_path = json_path
        self.json_data = json_data

    def get(self):
        jsonpath_expression = parse(self.json_path)
        match = jsonpath_expression.find(self.json_data)
        source_data_value = match[0].value
        return source_data_value

# %% [markdown]
# ### Combine it All - STTM

# %%
class STTM:
    def __init__(self, input_json):
        self.input_json = input_json
        self.mapping_instance = Mappings()
        self.source_instance = Source()
        self.destination_instance = Target()
        self.transform_instance = Transform()
        self.look_up_mask = {i.name: i.value for i in TransformMask}
        self.json_data_transformed = {}
        self.to_table = {}

    def _get_mapping_data(self):
        return self.mapping_instance.get

    def _get_mapping_source_data(self):
        return self.source_instance.get

    def get_transformed_data(self):

        for mappings in self._get_mapping_data():

            """fetch the source mapping """
            mapping_source_id = mappings.get("mapping_source")
            mapping_destination_id = mappings.get("mapping_destination")
            mapping_transform_id = mappings.get("mapping_transform")
            mapping_table = mappings.get("destination_table")

            mapping_source_data = self.source_instance.get_data_by_id(id=mapping_source_id)
            transform_data = self.transform_instance.get_data_by_id(id=mapping_transform_id)

            """Fetch Source  field Name"""
            source_field_name = mapping_source_data.get("source_field_name")

            """if field given is not present incoming json """
            if source_field_name not in self.input_json.keys():
                if mapping_source_data.get("is_required"):
                    raise Exception(
                        "Alert ! Field {} is not present in JSON please FIX mappings ".format(source_field_name))
                else:
                    pass

            else:
                source_data_value = JsonQuery(
                    json_path=mapping_source_data.get("source_field_mapping"),
                    json_data=self.input_json
                ).get()

                """check the data type for source if matches with what we have """
                if mapping_source_data.get("source_field_type") != type(source_data_value).__name__:
                    if source_data_value is not None:
                        _message = (
                            "Alert ! Source Field :{} Datatype has changed from {} to {} ".format(source_field_name,
                                                                                                  mapping_source_data.get(
                                                                                                      "source_field_type"),
                                                                                                  type(
                                                                                                      source_data_value).__name__))
                        print(_message)
                        raise Exception(_message)

                """Query and fetch the Destination | target """
                destination_mappings_json_object = self.destination_instance.get_data_by_id(
                    id=mappings.get("mapping_destination"))

                destination_field_name = destination_mappings_json_object.get("destination_field_name")
                destination_field_type = destination_mappings_json_object.get("destination_field_type")
                self.to_table[destination_field_name] = mapping_table

                dtypes = [str, float, list, int, set, dict]

                for dtype in dtypes:

                    """Datatype Conversion """
                    if destination_field_type == str(dtype.__name__):

                        """is source is none insert default value"""
                        if source_data_value is None: #(לבדוק שינוי זה)
                        #if source_data_value is None or source_data_value == 'n/a':
                            self.json_data_transformed[destination_field_name] = dtype.__call__(
                                destination_mappings_json_object.get("default_value")
                            )

                        else:
                            """check if you have items to transform"""
                            if transform_data is not None:
                                """ check for invalid mask name """
                                if transform_data.get("transform_mask") not in list(self.look_up_mask.keys()):
                                    raise Exception(
                                        f"Specified Transform {transform_data.get('transform_mask')} is not available please select from following Options :{list(self.look_up_mask.keys())}")
                                else:
                                    mask_apply = self.look_up_mask.get(transform_data.get("transform_mask"))
                                    converted_dtype = dtype.__call__(source_data_value)
                                    mask = f'converted_dtype{mask_apply}'
                                    curated_value = eval(mask)
                                    self.json_data_transformed[destination_field_name] = curated_value

                            else:
                                self.json_data_transformed[destination_field_name] = dtype.__call__(source_data_value)

        return self.json_data_transformed, self.to_table

# %%
transformed_data = []
for item in data:
    helper = STTM(input_json=item)
    response, mapping = helper.get_transformed_data()
    transformed_data.append(response)
    print(response)
print(mapping)
# Out:
# {'id': '12147973', 'price': 250.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 3}
# {'id': '3075044', 'price': 65.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '6976', 'price': 65.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '1436513', 'price': 75.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '7651065', 'price': 79.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '12386020', 'price': 75.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'condominium', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '5706985', 'price': 100.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '2843445', 'price': 75.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 2, 'bedrooms': 1, 'beds': 1}
# {'id': '753446', 'price': 58.0, 'city': 'roslindale', 'neighbourhood': 'roslindale', 'property_type': 'condominium', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '849408', 'price': 229.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 5, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '12023024', 'price': 60.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '1668313', 'price': 57.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '2684840', 'price': 93.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'condominium', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '13547301', 'price': 150.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 5, 'bathrooms': 1, 'bedrooms': 2, 'beds': 3}
# {'id': '5434353', 'price': 145.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '225979', 'price': 60.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 0, 'bedrooms': 1, 'beds': 1}
# {'id': '3420384', 'price': 165.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 1, 'beds': 3}
# {'id': '13512930', 'price': 75.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'condominium', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '7482195', 'price': 49.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '7252607', 'price': 49.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '2583074', 'price': 40.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'villa', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 2, 'bedrooms': 1, 'beds': 1}
# {'id': '13251243', 'price': 120.0, 'city': 'roslindale', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 0, 'beds': 2}
# {'id': '225834', 'price': 70.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 0, 'bedrooms': 1, 'beds': 1}
# {'id': '6400432', 'price': 150.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 8, 'bathrooms': 1, 'bedrooms': 3, 'beds': 5}
# {'id': '5498472', 'price': 175.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 5, 'bathrooms': 3, 'bedrooms': 4, 'beds': 3}
# {'id': '894539', 'price': 95.0, 'city': 'roslindale', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '879929', 'price': 90.0, 'city': 'roslindale', 'neighbourhood': 'roslindale', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '9218312', 'price': 95.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '321328', 'price': 100.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '1810172', 'price': 67.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '6513924', 'price': 55.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'condominium', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '7093109', 'price': 200.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 6, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '14690527', 'price': 150.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '7086825', 'price': 49.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '1861070', 'price': 75.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '4283698', 'price': 110.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '10116095', 'price': 115.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '8548176', 'price': 125.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 16, 'bathrooms': 1, 'bedrooms': 3, 'beds': 5}
# {'id': '4922204', 'price': 200.0, 'city': 'roslindale, boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 16, 'bathrooms': 2, 'bedrooms': 3, 'beds': 7}
# {'id': '4085362', 'price': 75.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 2, 'bedrooms': 1, 'beds': 1}
# {'id': '3755609', 'price': 78.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '13768853', 'price': 50.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '1936861', 'price': 60.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '4461111', 'price': 45.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '1724900', 'price': 145.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '13937181', 'price': 45.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 2, 'bedrooms': 1, 'beds': 1}
# {'id': '3968797', 'price': 85.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '1494726', 'price': 75.0, 'city': 'roslindale', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '8473851', 'price': 50.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 2, 'bedrooms': 1, 'beds': 1}
# {'id': '3575220', 'price': 45.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 2, 'bedrooms': 1, 'beds': 1}
# {'id': '1591827', 'price': 60.0, 'city': 'roslindale', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '3229255', 'price': 95.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '1721016', 'price': 89.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 0, 'beds': 1}
# {'id': '12535687', 'price': 110.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 0, 'beds': 2}
# {'id': '12994227', 'price': 65.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'condominium', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '12927298', 'price': 285.0, 'city': 'boston', 'neighbourhood': 'roslindale', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 7, 'bathrooms': 2, 'bedrooms': 3, 'beds': 3}
# {'id': '169938', 'price': 140.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '594693', 'price': 70.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '2384581', 'price': 95.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '735970', 'price': 55.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'bed & breakfast', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '4262255', 'price': 80.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '4000384', 'price': 120.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '6693305', 'price': 65.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '6730758', 'price': 100.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '6248970', 'price': 65.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '12806707', 'price': 60.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14246616', 'price': 63.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '3703674', 'price': 75.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'townhouse', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '4792901', 'price': 65.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '5717528', 'price': 110.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '5601743', 'price': 46.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '13333862', 'price': 75.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '519272', 'price': 62.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14090779', 'price': 69.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'condominium', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '8481291', 'price': 69.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '6990904', 'price': 73.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 2, 'bedrooms': 1, 'beds': 1}
# {'id': '197727', 'price': 85.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '932853', 'price': 120.0, 'city': 'jamaica plain', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 2, 'bedrooms': 1, 'beds': 1}
# {'id': '11159585', 'price': 125.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 3, 'bedrooms': 1, 'beds': 2}
# {'id': '9677354', 'price': 70.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '13426831', 'price': 100.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'condominium', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '7956634', 'price': 61.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'condominium', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '568234', 'price': 125.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '1030500', 'price': 100.0, 'city': 'jamaica plain', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '13652374', 'price': 27.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '12930651', 'price': 80.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '3997572', 'price': 85.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '4223387', 'price': 75.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '12855396', 'price': 57.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '12426823', 'price': 100.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14361322', 'price': 40.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '2963419', 'price': 100.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '5904732', 'price': 70.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 2, 'bedrooms': 1, 'beds': 1}
# {'id': '3591359', 'price': 190.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '2538536', 'price': 149.0, 'city': 'brookline', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '4975581', 'price': 168.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 6, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '4767023', 'price': 205.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 5, 'bathrooms': 2, 'bedrooms': 3, 'beds': 4}
# {'id': '6364042', 'price': 65.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 2, 'bedrooms': 1, 'beds': 1}
# {'id': '7986179', 'price': 75.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14109003', 'price': 117.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'condominium', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 4}
# {'id': '1109224', 'price': 429.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 8, 'bathrooms': 2, 'bedrooms': 4, 'beds': 6}
# {'id': '1067184', 'price': 95.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '13215952', 'price': 69.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '777903', 'price': 85.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 0, 'bedrooms': 1, 'beds': 1}
# {'id': '1301500', 'price': 69.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '8923817', 'price': 165.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14057466', 'price': 150.0, 'city': 'jamaica plain, boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '14909417', 'price': 267.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'condominium', 'room_type': 'entire home/apt', 'accommodates': 7, 'bathrooms': 1, 'bedrooms': 4, 'beds': 4}
# {'id': '5521378', 'price': 87.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '13041602', 'price': 62.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'townhouse', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '2621242', 'price': 110.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '950046', 'price': 250.0, 'city': 'jamaica plain', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 6, 'bathrooms': 2, 'bedrooms': 3, 'beds': 3}
# {'id': '3342094', 'price': 150.0, 'city': 'jamaica plain (boston)', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 6, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '5652147', 'price': 300.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 7, 'bathrooms': 2, 'bedrooms': 3, 'beds': 4}
# {'id': '14105971', 'price': 119.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 0, 'beds': 1}
# {'id': '2875267', 'price': 175.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 0, 'beds': 1}
# {'id': '9485607', 'price': 195.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 6, 'bathrooms': 2, 'bedrooms': 2, 'beds': 2}
# {'id': '7273770', 'price': 145.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'condominium', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '5405928', 'price': 200.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '4586681', 'price': 90.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '1113272', 'price': 210.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '12647606', 'price': 75.0, 'city': 'jamaica plain', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '10271867', 'price': 46.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '7879708', 'price': 75.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'condominium', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '3881993', 'price': 500.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 6, 'bathrooms': 1, 'bedrooms': 3, 'beds': 3}
# {'id': '12566065', 'price': 60.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '6602217', 'price': 130.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 5, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '3276286', 'price': 190.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 6, 'bathrooms': 1, 'bedrooms': 2, 'beds': 3}
# {'id': '2014651', 'price': 100.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '6053700', 'price': 450.0, 'city': 'jamaica plain', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 6, 'bathrooms': 3, 'bedrooms': 3, 'beds': 6}
# {'id': '4405982', 'price': 399.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 8, 'bathrooms': 2, 'bedrooms': 4, 'beds': 4}
# {'id': '250983', 'price': 350.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 5, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '2308630', 'price': 200.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '8272350', 'price': 99.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '12368012', 'price': 295.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 6, 'bathrooms': 2, 'bedrooms': 3, 'beds': 4}
# {'id': '4098410', 'price': 107.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '6322283', 'price': 69.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '7823025', 'price': 76.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '9549850', 'price': 75.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '7845607', 'price': 55.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14071446', 'price': 65.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '14218904', 'price': 59.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'condominium', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '11826815', 'price': 88.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '13334098', 'price': 164.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 5, 'bathrooms': 2, 'bedrooms': 4, 'beds': 3}
# {'id': '4765070', 'price': 90.0, 'city': 'jamaica plain', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 0, 'beds': 1}
# {'id': '2880944', 'price': 185.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 2, 'bedrooms': 2, 'beds': 2}
# {'id': '9532771', 'price': 80.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '10253591', 'price': 105.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '1881298', 'price': 90.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '210097', 'price': 100.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '6059968', 'price': 100.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'shared room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '6862758', 'price': 200.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 5, 'bathrooms': 1, 'bedrooms': 2, 'beds': 3}
# {'id': '799701', 'price': 300.0, 'city': 'jamaica plain', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 8, 'bathrooms': 1, 'bedrooms': 4, 'beds': 4}
# {'id': '6862594', 'price': 60.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '9057435', 'price': 319.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 6, 'bathrooms': 1, 'bedrooms': 3, 'beds': 3}
# {'id': '750438', 'price': 85.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '12874603', 'price': 70.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'condominium', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 2, 'bedrooms': 1, 'beds': 1}
# {'id': '12727401', 'price': 50.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '2077794', 'price': 119.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '9712731', 'price': 125.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'condominium', 'room_type': 'entire home/apt', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '13677640', 'price': 53.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '3371091', 'price': 125.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '13512551', 'price': 199.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 6, 'bathrooms': 2, 'bedrooms': 4, 'beds': 4}
# {'id': '732999', 'price': 205.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '6106955', 'price': 114.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'condominium', 'room_type': 'entire home/apt', 'accommodates': 5, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '2698996', 'price': 75.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '27611', 'price': 185.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '4025194', 'price': 75.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '8336364', 'price': 180.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 2, 'bedrooms': 2, 'beds': 2}
# {'id': '12071820', 'price': 70.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'shared room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '7910223', 'price': 150.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'bed & breakfast', 'room_type': 'entire home/apt', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '4567815', 'price': 120.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '12022134', 'price': 92.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 2, 'bedrooms': 1, 'beds': 1}
# {'id': '13513012', 'price': 84.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '3730447', 'price': 200.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '4149974', 'price': 115.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14933380', 'price': 49.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'shared room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '6238463', 'price': 95.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'townhouse', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '1929406', 'price': 275.0, 'city': 'jamaica plain', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 6, 'bathrooms': 1, 'bedrooms': 4, 'beds': 4}
# {'id': '4583526', 'price': 230.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 9, 'bathrooms': 1, 'bedrooms': 4, 'beds': 4}
# {'id': '7287822', 'price': 130.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 1, 'beds': 4}
# {'id': '8354938', 'price': 192.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 5, 'bathrooms': 1, 'bedrooms': 2, 'beds': 3}
# {'id': '5025015', 'price': 175.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 5, 'bathrooms': 1, 'bedrooms': 3, 'beds': 4}
# {'id': '4452800', 'price': 70.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '7554801', 'price': 65.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'townhouse', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '9349646', 'price': 100.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '6386351', 'price': 185.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '5124772', 'price': 250.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 10, 'bathrooms': 2, 'bedrooms': 5, 'beds': 5}
# {'id': '3977877', 'price': 110.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '1754939', 'price': 150.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 5, 'bathrooms': 1, 'bedrooms': 2, 'beds': 3}
# {'id': '6602167', 'price': 168.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 6, 'bathrooms': 1, 'bedrooms': 2, 'beds': 4}
# {'id': '3987926', 'price': 60.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '5729845', 'price': 59.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '9727523', 'price': 60.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '12463555', 'price': 145.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 4}
# {'id': '9137560', 'price': 80.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '3616081', 'price': 114.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '8908145', 'price': 170.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '554720', 'price': 240.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 6, 'bathrooms': 2, 'bedrooms': 2, 'beds': 2}
# {'id': '1551467', 'price': 150.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '7743569', 'price': 69.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '732932', 'price': 80.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '749247', 'price': 85.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '667325', 'price': 75.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '9349614', 'price': 150.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '10627514', 'price': 70.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 2, 'bedrooms': 1, 'beds': 1}
# {'id': '1885825', 'price': 80.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '9906565', 'price': 225.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 7, 'bathrooms': 1, 'bedrooms': 3, 'beds': 4}
# {'id': '629814', 'price': 225.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '1222327', 'price': 178.0, 'city': 'jamaica plain', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 2, 'bedrooms': 2, 'beds': 2}
# {'id': '10299047', 'price': 175.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '9463444', 'price': 109.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 0, 'beds': 2}
# {'id': '6465075', 'price': 383.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'condominium', 'room_type': 'entire home/apt', 'accommodates': 10, 'bathrooms': 2, 'bedrooms': 5, 'beds': 6}
# {'id': '8932377', 'price': 90.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'condominium', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '9577988', 'price': 99.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 6, 'bathrooms': 1, 'bedrooms': 2, 'beds': 3}
# {'id': '9971054', 'price': 50.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '7348110', 'price': 300.0, 'city': 'roxbury crossing', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '7790454', 'price': 184.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 6, 'bathrooms': 2, 'bedrooms': 4, 'beds': 5}
# {'id': '3021446', 'price': 80.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '7708436', 'price': 85.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '11514237', 'price': 150.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '13363171', 'price': 100.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '11946029', 'price': 100.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '6019555', 'price': 84.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'townhouse', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '12052288', 'price': 130.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '9676551', 'price': 76.0, 'city': 'jamaica plain', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '12789527', 'price': 100.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '12855005', 'price': 70.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 2, 'bedrooms': 1, 'beds': 1}
# {'id': '1631942', 'price': 125.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'condominium', 'room_type': 'entire home/apt', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '2884903', 'price': 70.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14868157', 'price': 75.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'bed & breakfast', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '13344433', 'price': 170.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 2, 'beds': 1}
# {'id': '40601', 'price': 95.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '12033661', 'price': 70.0, 'city': 'boston', 'neighbourhood': 'jamaica plain', 'property_type': 'bed & breakfast', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# ...
# {'id': '8882195', 'price': 139.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 0}
# {'id': '14473323', 'price': 239.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 2, 'bedrooms': 2, 'beds': 2}
# {'id': '8029788', 'price': 200.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '1902160', 'price': 72.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '7783953', 'price': 128.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '7931331', 'price': 269.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 6, 'bathrooms': 2, 'bedrooms': 2, 'beds': 3}
# {'id': '6277566', 'price': 230.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'townhouse', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '9570618', 'price': 120.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'condominium', 'room_type': 'private room', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '3609536', 'price': 70.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '9470342', 'price': 50.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '2672058', 'price': 85.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14572086', 'price': 150.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '13451383', 'price': 80.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14773223', 'price': 67.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '9078482', 'price': 45.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 2, 'bedrooms': 1, 'beds': 1}
# {'id': '4032126', 'price': 40.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '8704828', 'price': 69.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14303761', 'price': 55.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '4964365', 'price': 180.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 5, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '13681910', 'price': 279.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 6, 'bathrooms': 2, 'bedrooms': 3, 'beds': 3}
# {'id': '10208321', 'price': 50.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '12026868', 'price': 25.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '11043756', 'price': 60.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'house', 'room_type': 'shared room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '7462268', 'price': 75.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 2, 'bedrooms': 1, 'beds': 1}
# {'id': '7602994', 'price': 28.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '6373729', 'price': 75.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '8921130', 'price': 129.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '10436811', 'price': 50.0, 'city': 'boston', 'neighbourhood': 'allston-brighton', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14026059', 'price': 75.0, 'city': 'brookline', 'neighbourhood': 'brookline', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 2, 'bedrooms': 1, 'beds': 1}
# {'id': '14503389', 'price': 85.0, 'city': 'cambridge', 'neighbourhood': '', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14610297', 'price': 155.0, 'city': 'brookline', 'neighbourhood': 'brookline', 'property_type': 'bed & breakfast', 'room_type': 'private room', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '4332035', 'price': 272.0, 'city': 'brookline', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '9807292', 'price': 350.0, 'city': 'brookline', 'neighbourhood': 'brookline', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 5, 'bathrooms': 2, 'bedrooms': 2, 'beds': 2}
# {'id': '7789055', 'price': 329.0, 'city': 'cambridge', 'neighbourhood': 'cambridge', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 8, 'bathrooms': 2, 'bedrooms': 3, 'beds': 5}
# {'id': '14902894', 'price': 140.0, 'city': 'cambridge', 'neighbourhood': 'cambridge', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 1, 'beds': 3}
# {'id': '14866400', 'price': 70.0, 'city': 'somerville', 'neighbourhood': 'somerville', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 2, 'bedrooms': 1, 'beds': 1}
# {'id': '14584547', 'price': 295.0, 'city': 'cambridge', 'neighbourhood': 'cambridge', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '14400847', 'price': 80.0, 'city': 'somerville', 'neighbourhood': 'somerville', 'property_type': 'condominium', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14510982', 'price': 240.0, 'city': 'cambridge', 'neighbourhood': 'cambridge', 'property_type': 'house', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 2}
# {'id': '14848154', 'price': 88.0, 'city': 'somerville', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '14774426', 'price': 80.0, 'city': 'somerville', 'neighbourhood': 'somerville', 'property_type': 'entire floor', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14487346', 'price': 80.0, 'city': 'somerville', 'neighbourhood': 'somerville', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14550228', 'price': 113.0, 'city': 'cambridge', 'neighbourhood': 'cambridge', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14566657', 'price': 180.0, 'city': 'cambridge', 'neighbourhood': 'cambridge', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14773792', 'price': 47.0, 'city': 'somerville', 'neighbourhood': 'somerville', 'property_type': 'apartment', 'room_type': 'shared room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14874204', 'price': 69.0, 'city': 'somerville', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14533848', 'price': 125.0, 'city': 'brookline', 'neighbourhood': '', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '13015653', 'price': 39.0, 'city': 'brookline', 'neighbourhood': 'brookline', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14849141', 'price': 69.0, 'city': 'somerville', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14604429', 'price': 60.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 0}
# {'id': '14592644', 'price': 195.0, 'city': 'cambridge', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 2, 'beds': 1}
# {'id': '12915510', 'price': 229.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'boat', 'room_type': 'private room', 'accommodates': 7, 'bathrooms': 1, 'bedrooms': 1, 'beds': 5}
# {'id': '14887382', 'price': 249.0, 'city': 'somerville', 'neighbourhood': 'somerville', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 7, 'bathrooms': 1, 'bedrooms': 3, 'beds': 3}
# {'id': '14823430', 'price': 72.0, 'city': 'brookline', 'neighbourhood': '', 'property_type': 'loft', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '14881840', 'price': 179.0, 'city': 'boston', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'shared room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '11452297', 'price': 199.0, 'city': 'somerville', 'neighbourhood': 'somerville', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 6, 'bathrooms': 2, 'bedrooms': 2, 'beds': 3}
# {'id': '14576706', 'price': 75.0, 'city': 'somerville', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14335003', 'price': 146.0, 'city': 'cambridge', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '14871445', 'price': 85.0, 'city': 'brookline', 'neighbourhood': 'brookline', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14472678', 'price': 259.0, 'city': 'cambridge', 'neighbourhood': 'harvard square', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 10, 'bathrooms': 3, 'bedrooms': 5, 'beds': 5}
# {'id': '14574800', 'price': 69.0, 'city': 'somerville', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14426586', 'price': 200.0, 'city': 'somerville', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 1, 'beds': 2}
# {'id': '3131519', 'price': 72.0, 'city': 'cambridge', 'neighbourhood': 'somerville', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14592547', 'price': 89.0, 'city': 'brookline', 'neighbourhood': 'brookline', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14744740', 'price': 459.0, 'city': 'cambridge', 'neighbourhood': 'harvard square', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 9, 'bathrooms': 2, 'bedrooms': 5, 'beds': 5}
# {'id': '14504583', 'price': 65.0, 'city': 'somerville', 'neighbourhood': 'somerville', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14743129', 'price': 68.0, 'city': '', 'neighbourhood': 'chestnut hill', 'property_type': 'townhouse', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '5280827', 'price': 69.0, 'city': 'somerville', 'neighbourhood': 'somerville', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14689681', 'price': 124.0, 'city': 'cambridge', 'neighbourhood': 'cambridge', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '13750763', 'price': 150.0, 'city': 'brookline', 'neighbourhood': 'brookline', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14536322', 'price': 85.0, 'city': 'cambridge', 'neighbourhood': '', 'property_type': 'house', 'room_type': 'private room', 'accommodates': 1, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14852179', 'price': 100.0, 'city': 'brookline', 'neighbourhood': 'brookline', 'property_type': 'condominium', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '8373729', 'price': 69.0, 'city': 'somerville', 'neighbourhood': 'somerville', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 3, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14844274', 'price': 150.0, 'city': 'brookline', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14585486', 'price': 198.0, 'city': 'cambridge', 'neighbourhood': '', 'property_type': 'apartment', 'room_type': 'entire home/apt', 'accommodates': 4, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14603878', 'price': 65.0, 'city': 'somerville', 'neighbourhood': 'somerville', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': '14504422', 'price': 65.0, 'city': 'somerville', 'neighbourhood': 'somerville', 'property_type': 'apartment', 'room_type': 'private room', 'accommodates': 2, 'bathrooms': 1, 'bedrooms': 1, 'beds': 1}
# {'id': 'fact', 'price': 'fact', 'city': 'dim_property', 'neighbourhood': 'dim_property', 'property_type': 'dim_property', 'room_type': 'dim_property', 'accommodates': 'dim_property', 'bathrooms': 'dim_property', 'bedrooms': 'dim_property', 'beds': 'dim_property'}

# %%
pd.DataFrame(transformed_data)
# Out:
#             id  price        city neighbourhood property_type  \
# 0     12147973  250.0      boston    roslindale         house
# 1      3075044   65.0      boston    roslindale     apartment
# 2         6976   65.0      boston    roslindale     apartment
# 3      1436513   75.0      boston                       house
# 4      7651065   79.0      boston    roslindale         house
# ...        ...    ...         ...           ...           ...
# 3580   8373729   69.0  somerville    somerville     apartment
# 3581  14844274  150.0   brookline                   apartment
# 3582  14585486  198.0   cambridge                   apartment
# 3583  14603878   65.0  somerville    somerville     apartment
# 3584  14504422   65.0  somerville    somerville     apartment
#
#             room_type  accommodates  bathrooms  bedrooms  beds
# 0     entire home/apt             4          1         2     3
# 1        private room             2          1         1     1
# 2        private room             2          1         1     1
# 3        private room             4          1         1     2
# 4        private room             2          1         1     2
# ...               ...           ...        ...       ...   ...
# 3580     private room             3          1         1     1
# 3581     private room             2          1         1     1
# 3582  entire home/apt             4          1         1     1
# 3583     private room             2          1         1     1
# 3584     private room             2          1         1     1
#
# [3585 rows x 10 columns]

# %%
import pandas as pd

# Assuming transformed_data is a list
transformed_data = pd.DataFrame(transformed_data)  # Convert list to DataFrame

transformed_data.to_csv('output.csv', index=False)  # Export DataFrame to CSV

# %% [markdown]
# Attached FILE CSV = output
#
# ```

# %% [markdown]
# # Data Warehouse Analysis

# %%
SELECT neighbourhood, AVG(price) OVER (PARTITION BY neighbourhood) AS "price_avg_neighbrhd"
FROM location, fact
WHERE location.id = fact.id
GROUP by neighbourhood
order by 2 DESC;
/********/

SELECT accommodates, bedrooms, bathrooms,  AVG(price) OVER (PARTITION BY bathrooms,bedrooms, accommodates) AS "price_avg_bb"
FROM property, fact
WHERE property.id = fact.id
GROUP by bathrooms, bedrooms, accommodates
order by 3, 2, 1 DESC;
/*********/

SELECT neighbourhood, property_type, count(*) as "num of properties" , AVG(price) OVER (PARTITION BY neighbourhood, property_type) as "price_avg_np"
FROM location, property, fact
WHERE property.id = fact.id
AND location.id = fact.id
GROUP by 1,2
order by 1, 2,3 desc;
/*********/

select AVG(accommodates), neighbourhood,  AVG(price) OVER (PARTITION BY accommodates, neighbourhood) AS "price_avg_an"
FROM location, property, fact
WHERE property.id = fact.id
AND location.id = fact.id
GROUP by 2
order by 1,2 DESC;
/*********/

SELECT cancellation_policy,  AVG(price) OVER (PARTITION BY cancellation_policy) AS "price_avg_cp"
FROM property , fact
WHERE property.id = fact.id
GROUP by 1
order by 1 DESC;
/*********/

SELECT  neighbourhood, property_type,  (AVG(price) OVER (PARTITION BY accommodates, property_type)) / avg(accommodates)  AS "price_avg per person"
FROM location, property, fact
WHERE property.id = fact.id
AND location.id = fact.id
GROUP by 1,2
order by 1 DESC;
/*********/

SELECT neighbourhood, property_type, MAX(price) OVER (PARTITION BY neighbourhood, property_type) AS 'MAX_PRICE',
MIN(price) OVER (PARTITION BY neighbourhood, property_type) AS 'MIN_PRICE'
FROM location, property, fact
WHERE property.id = fact.id
AND location.id = fact.id
GROUP BY 1,2
ORDER BY 1,2;
/*********/

SELECT neighbourhood, room_type,  AVG(price) OVER (PARTITION BY neighbourhood, room_type) AS "price_avg_nr"
FROM location, property, fact
WHERE property.id = fact.id
AND location.id = fact.id
GROUP by 1,2
order by 1,2 DESC;
/*********/

# %% [markdown]
# #Conclusions

# %% [markdown]
# 1. The average prices vary across different neighborhoods, indicating that location plays a significant role in determining property prices.
#
# 2. The average prices differ based on the combination of accommodation details such as the number of bedrooms, bathrooms, and the capacity to accommodate guests.
#
# 3. The average price differs based on the cancellation policy, implying that the flexibility of cancellation policies may influence property prices.
#
# 4. The average price per person varies across neighborhoods and property types, indicating that the cost of accommodation per person can differ based on the specific location and property type.
#
#
# Overall, these queries allow us to have insights into the average prices, price variations, and other statistical information related to different criteria such as neighborhood, accommodation details, property type, cancellation policy, and room type. They help in understanding the pricing dynamics within a given dataset and can assist in making informed decisions related to property investments, pricing strategies, and customer preferences.
